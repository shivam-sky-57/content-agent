# %%
from dotenv import load_dotenv

load_dotenv()

# %%
import os 

GOOGLE_GEMINI_API_KEY = os.environ.get("GOOGLE_GEMINI_API_KEY")
assert GOOGLE_GEMINI_API_KEY is not None

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("gemini-3.5-flash", model_provider="google_genai", api_key=GOOGLE_GEMINI_API_KEY)

# %%
from pydantic import BaseModel, Field

# %%
class LanguageRanking(BaseModel):
    name: str = Field(description="Programming language name")
    date_created: str = Field(description="data firsst created")
    rank: int = Field(description="Current ranking") 

class ProgrammingLanguageRank(BaseModel):
    rankings: list[LanguageRanking] = Field(description="current rankings of programmming languages")

# %%
llm = model.with_structured_output(ProgrammingLanguageRank)

# %%
result = llm.invoke("What is the popularity ranking of programming language in the world")

# %%
result.model_dump()

# %%
for lang in result.rankings:
    print(lang.name, lang.date_created, lang.rank)
